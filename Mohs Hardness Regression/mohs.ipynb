# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/12th Grade/Machine Learning/Data/Mohs Hardness/train.csv')

# %%
df.head()
# Out:
#    id  allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0   0               100.0       0.841611                  10.0            4.8
# 1   1               100.0       7.558488                  10.0            4.8
# 2   2                76.0       8.885992                  15.6            5.6
# 3   3               100.0       8.795296                  10.0            4.8
# 4   4               116.0       9.577996                  11.6            4.8
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0             20.612526           11.08810               2.766
# 1             20.298893           12.04083               2.755
# 2             33.739258           12.08630               2.828
# 3             20.213349           10.94850               2.648
# 4             24.988133           11.82448               2.766
#
#    R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# ...

# %%
df.isna().sum()
# Out:
# id                       0
# allelectrons_Total       0
# density_Total            0
# allelectrons_Average     0
# val_e_Average            0
# atomicweight_Average     0
# ionenergy_Average        0
# el_neg_chi_Average       0
# R_vdw_element_Average    0
# R_cov_element_Average    0
# zaratio_Average          0
# density_Average          0
# Hardness                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Hardness'],
#       dtype='object')

# %%
features = ['allelectrons_Total', 'density_Total', 'allelectrons_Average',
       'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
       'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
       'zaratio_Average', 'density_Average']

# %%
import seaborn as sns

sns.pairplot(df, x_vars=features, y_vars='Hardness', height = 7, aspect = 0.7, kind='reg')

# %%
X=df[features]
y=df['Hardness']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

linreg.fit(X_train, y_train)

y_pred = linreg.predict(X_test)

# %%
from sklearn import metrics

print(metrics.median_absolute_error(y_test, y_pred))
# Out:
# 0.9607276902844588

# %%
df_new = pd.read_csv('/content/drive/MyDrive/12th Grade/Machine Learning/Data/Mohs Hardness/test.csv')

# %%
df_new.isna().sum()
# Out:
# id                       0
# allelectrons_Total       0
# density_Total            0
# allelectrons_Average     0
# val_e_Average            0
# atomicweight_Average     0
# ionenergy_Average        0
# el_neg_chi_Average       0
# R_vdw_element_Average    0
# R_cov_element_Average    0
# zaratio_Average          0
# density_Average          0
# dtype: int64

# %%
X_new = df_new[features]

# %%
linreg.fit(X,y)
y_res = linreg.predict(X_new)

# %%
res = pd.DataFrame({'id': df_new['id'], 'Hardness': y_res})

# %%
res.to_csv('/content/drive/MyDrive/12th Grade/Machine Learning/Data/Mohs Hardness/result.csv', index=False)
